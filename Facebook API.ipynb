# %%
import requests

# %%
url = "http://graph.facebook.com/4/picture?type=large"

# %%
r = requests.get(url)

# %%
print(r.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x141DQJaxNEjnxUqnzcbHjj\x1c\x02(\x00bFBMD01000aa4010000600300004505000006060000a0060000a2080000f00a0000a90b00004e0c0000e60c0000b0100000\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc2\x00\x11\x08\x00\xc8\x00\xc8\x03\x00"\x0
# ...

# %%
with open("sample_pic.jpg","wb") as f:
    f.write(r.content)
